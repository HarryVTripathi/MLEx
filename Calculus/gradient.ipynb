# %%
import numpy as np
from sympy import *
from matplotlib import pyplot as plt

# %%
x, y, z, t = symbols('x y z t')
#f = diff(cos(x), x)
df = lambdify(x, diff(x**3 + 1, x), 'numpy')

X = np.arange(-5, 6, 0.02)
Y = df(X)

plt.plot(X, Y)
plt.show()
