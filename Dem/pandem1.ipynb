# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Reading CSV file as dataframe

# %%
df1 = pd.read_csv('C:\\Users\\Harry\\Documents\\DS\\Datasets\\WBCD.csv')

# Printing first 5 values, default value is 5
df1.head()
# Out:
#         %id diagnosis (M=malignant; B=benign)  radius (nucA)  texture (nucA)  \
# 0    842302                                 M          17.99           10.38
# 1    842517                                 M          20.57           17.77
# 2  84300903                                 M          19.69           21.25
# 3  84348301                                 M          11.42           20.38
# 4  84358402                                 M          20.29           14.34
#
#    perimeter (nucA)  area (nucA)  smoothness (nucA)  compactness (nucA)  \
# 0            122.80       1001.0            0.11840             0.27760
# 1            132.90       1326.0            0.08474             0.07864
# 2            130.00       1203.0            0.10960             0.15990
# 3             77.58        386.1            0.14250             0.28390
# 4            135.10       1297.0            0.10030             0.13280
#
#    concavity (nucA)  concave points (nucA)  ...  radius (nucC)  \
# ...

# %%
# Printing last 6 values
df1.tail(6)

# %%
df1.dtypes

# %%
# Prints the info about column being used to index
df1.index

# %%
# Sorting the indices in ascending order
# axis=0 implies row indices [0: 569]
# axis=1 implies column indices [%id to 'fractal dimension (nucC)']

df1.sort_index(axis=0, ascending=False).head(10)

# %%
# Sorting according to a certain feature/column
df1.sort_values(by='area (nucA)').head(6)

# %%
# Prints all the columns
df1.columns

# %% [markdown]
# <br>
# <br>
# #### Selecting

# %%
# Selecting a single column, which yields a Series, equivalent to df.radius
df1['radius (nucA)'].head(25).tail(5)

# And that's precisely why multiple columns CANNOT be selected

# %%
# Slicing the rows
df1[9:15]
# If [:15], return rows from starting to 14

# %%
df1.loc[12:21, ['radius (nucA)', 'area (nucA)']]

# Also try
# df1.loc["12":21]
# df1.loc[12:21]

# %%
# Reduction in the dimensions of the returned object:
df1.loc[12, ['radius (nucA)', 'area (nucA)']]

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# #### Selection by position

# %%
# Select via the position of the passed integers:
# df1.iloc[6]
# This will select the row with ith index
# iloc => index location

# %%
# By integer slices, acting similar to numpy/python
df1.iloc[3:5, 3:5]

# %%
# By lists of integer position locations, similar to the numpy/python style:
df1.iloc[[1, 2, 4], [2, 3, 4]]

# %%
# For slicing rows explicitly:
df1.iloc[1:3, :]
# Out:
#         %id diagnosis (M=malignant; B=benign)  radius (nucA)  texture (nucA)  \
# 1    842517                                 M          20.57           17.77
# 2  84300903                                 M          19.69           21.25
#
#    perimeter (nucA)  area (nucA)  smoothness (nucA)  compactness (nucA)  \
# 1             132.9       1326.0            0.08474             0.07864
# 2             130.0       1203.0            0.10960             0.15990
#
#    concavity (nucA)  concave points (nucA)  ...  radius (nucC)  \
# 1            0.0869                0.07017  ...          24.99
# 2            0.1974                0.12790  ...          23.57
#
#    texture (nucC)  perimeter (nucC)  area (nucC)  smoothness (nucC)  \
# 1           23.41             158.8       1956.0             0.1238
# 2           25.53             152.5       1709.0             0.1444
#
#    compactness (nucC)  concavity (nucC)  concave points (nucC)  \
# ...

# %%
# For slicing columns explicitly:
df1.iloc[:, 3:6]
# Out:
#      texture (nucA)  perimeter (nucA)  area (nucA)
# 0             10.38            122.80       1001.0
# 1             17.77            132.90       1326.0
# 2             21.25            130.00       1203.0
# 3             20.38             77.58        386.1
# 4             14.34            135.10       1297.0
# ..              ...               ...          ...
# 564           22.39            142.00       1479.0
# 565           28.25            131.20       1261.0
# 566           28.08            108.30        858.1
# 567           29.33            140.10       1265.0
# 568           24.54             47.92        181.0
#
# [569 rows x 3 columns]

# %%
# For getting a value explicitly:
df1.iloc[1, 4]

# %% [markdown]
# <br>
# <br>
# #### Boolean indexing

# %%
# Using a single column’s values to select data.
df1[df1['radius (nucA)'] > 20].head(6)
# Out:
#          %id diagnosis (M=malignant; B=benign)  radius (nucA)  texture (nucA)  \
# 1     842517                                 M          20.57           17.77
# 4   84358402                                 M          20.29           14.34
# 23    851509                                 M          21.16           23.04
# 78   8610862                                 M          20.18           23.97
# 82   8611555                                 M          25.22           24.91
# 95     86208                                 M          20.26           23.03
#
#     perimeter (nucA)  area (nucA)  smoothness (nucA)  compactness (nucA)  \
# 1              132.9       1326.0            0.08474             0.07864
# 4              135.1       1297.0            0.10030             0.13280
# 23             137.2       1404.0            0.09428             0.10220
# 78             143.7       1245.0            0.12860             0.34540
# ...

# %%
df1[df1['%id'] % 24 == 0].head(6)
# Out:
#         %id diagnosis (M=malignant; B=benign)  radius (nucA)  texture (nucA)  \
# 24   852552                                 M         16.650           21.38
# 66   859464                                 B          9.465           21.01
# 90   861648                                 B         14.620           24.02
# 95    86208                                 M         20.260           23.03
# 119  865128                                 M         17.950           20.01
# 246  884448                                 B         13.200           17.43
#
#      perimeter (nucA)  area (nucA)  smoothness (nucA)  compactness (nucA)  \
# 24             110.00        904.6            0.11210             0.14570
# 66              60.11        269.4            0.10440             0.07773
# 90              94.57        662.7            0.08974             0.08606
# 95             132.40       1264.0            0.09078             0.13130
# ...

# %%
# Selecting values from a DataFrame where a boolean condition is met
df2 = df1[df1 > 0.1].head(20)
df2.head(10)
# The positions where conditions don't meet will come with "NaN" Values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-59f82d55ecb8> in <module>()
#       1 # Selecting values from a DataFrame where a boolean condition is met
# ----> 2 df2 = df1[df1 > 0.1].head(20)
#       3 df2.head(10)
#       4 # The positions where conditions don't meet will come with "NaN" Values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#    1577             # straight boolean comparisons we want to allow all columns
#    1578             # (regardless of dtype to pass thru) See #4537 for discussion.
# -> 1579             res = self._combine_const(other, func)
#    1580             return res.fillna(True).astype(bool)
#    1581
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func)
#    5394     def _combine_const(self, other, func):
# ...

# %%
# Using the isin() method for filtering
df2[df2['concave points (nucA)'].isin(['NaN'])].sort_values(by='area (nucA)')
# "is in"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-1b42951fb13f> in <module>()
#       1 # Using the isin() method for filtering
# ----> 2 df2[df2['concave points (nucA)'].isin(['NaN'])].sort_values(by='area (nucA)')
#       3 # "is in"
#
# NameError: name 'df2' is not defined

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# #### Setting values

# %%
df3 = df1.drop(['diagnosis (M=malignant; B=benign)'], axis=1).rename(columns={'%id': 'id', 'radius (nucA)': 'radius'})
# or we can also do: df1.drop(columns=['diagnosis (M=malignant; B=benign)])
df3 = df3.rename_axis('SNo')
df_arr = df3.to_numpy()

# %%
# Setting values for a whole:
df3.loc[:, 'id'] = np.array(np.random.randn(len(df3)))
df3.head().sort_values(by='id')
# Out:
#            id  radius  texture (nucA)  perimeter (nucA)  area (nucA)  \
# SNo
# 3   -1.575996   11.42           20.38             77.58        386.1
# 1   -0.404473   20.57           17.77            132.90       1326.0
# 0   -0.064748   17.99           10.38            122.80       1001.0
# 2   -0.023481   19.69           21.25            130.00       1203.0
# 4    0.321047   20.29           14.34            135.10       1297.0
#
#      smoothness (nucA)  compactness (nucA)  concavity (nucA)  \
# SNo
# 3              0.14250             0.28390            0.2414
# 1              0.08474             0.07864            0.0869
# 0              0.11840             0.27760            0.3001
# 2              0.10960             0.15990            0.1974
# 4              0.10030             0.13280            0.1980
#
#      concave points (nucA)  symmetry (nucA)  ...  radius (nucC)  \
# SNo                                          ...
# ...

# %% [markdown]
# <br>
# <br>
# ### Missing data
# #### Pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df3 = df3[df3 > 0.1]
df3.head(10)
# Out:
#            id  radius  texture (nucA)  perimeter (nucA)  area (nucA)  \
# SNo
# 0         NaN   17.99           10.38            122.80       1001.0
# 1         NaN   20.57           17.77            132.90       1326.0
# 2         NaN   19.69           21.25            130.00       1203.0
# 3         NaN   11.42           20.38             77.58        386.1
# 4    0.321047   20.29           14.34            135.10       1297.0
# 5    0.151185   12.45           15.70             82.57        477.1
# 6         NaN   18.25           19.98            119.60       1040.0
# 7    0.555442   13.71           20.83             90.20        577.9
# 8    0.793558   13.00           21.82             87.50        519.8
# 9    0.484400   12.46           24.04             83.97        475.9
#
#      smoothness (nucA)  compactness (nucA)  concavity (nucA)  \
# SNo
# 0               0.1184              0.2776            0.3001
# 1                  NaN                 NaN               NaN
# ...

# %%
# To drop any rows that have missing data.
df3.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [id, radius, texture (nucA), perimeter (nucA), area (nucA), smoothness (nucA), compactness (nucA), concavity (nucA), concave points (nucA), symmetry (nucA), fractal dimension (nucA), radius (nucB), texture (nucB), perimeter (nucB), area (nucB), smoothness (nucB), compactness (nucB), concavity (nucB), concave points (nucB), symmetry (nucB), fractal dimension (nucB), radius (nucC), texture (nucC), perimeter (nucC), area (nucC), smoothness (nucC), compactness (nucC), concavity (nucC), concave points (nucC), symmetry (nucC), fractal dimension (nucC)]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Filling missing data
df3.fillna(value=0.10).head(10)
# Out:
#            id  radius  texture (nucA)  perimeter (nucA)  area (nucA)  \
# SNo
# 0    0.100000   17.99           10.38            122.80       1001.0
# 1    0.100000   20.57           17.77            132.90       1326.0
# 2    0.100000   19.69           21.25            130.00       1203.0
# 3    0.100000   11.42           20.38             77.58        386.1
# 4    0.321047   20.29           14.34            135.10       1297.0
# 5    0.151185   12.45           15.70             82.57        477.1
# 6    0.100000   18.25           19.98            119.60       1040.0
# 7    0.555442   13.71           20.83             90.20        577.9
# 8    0.793558   13.00           21.82             87.50        519.8
# 9    0.484400   12.46           24.04             83.97        475.9
#
#      smoothness (nucA)  compactness (nucA)  concavity (nucA)  \
# SNo
# 0               0.1184              0.2776            0.3001
# 1               0.1000              0.1000            0.1000
# ...

# %% [markdown]
# <br>
# <br>
# <br>
# #### Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
print(df2)

# %%
df2.dtypes
